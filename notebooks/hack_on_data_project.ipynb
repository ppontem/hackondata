# %%
# %pylab inline
import seaborn as sns
sns.set(palette='Set3', font_scale=1.3)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob

# %%
import pandas as pd

# %%
ls
# Out:
# hack_on_data_project.ipynb

# %%
../data/

# %%
path = r'../data/ticket_data/' # use your path
allFiles = glob.glob(path + "/*2015*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
data2015 = pd.concat(list_)

# %%
path = r'../data/ticket_data/' # use your path
allFiles = glob.glob(path + "/*2014*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
data2014 = pd.concat(list_)

# %%
data2013 = pd.read_

# %%
data2013 = pd.read_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9da51438365> in <module>()
#       1 path = r'parking_tickets_2013/' # use your path
# ----> 2 allFiles = glob.glob(path + "/*.csv")
#       3 frame = pd.DataFrame()
#       4 list_ = []
#       5 for file_ in allFiles:
#
# NameError: name 'glob' is not defined

# %%
data2014.date_of_infraction = pd.to_datetime(data2014.date_of_infraction, format="%Y%m%d")

# %%
data.date_of_infraction = pd.to_datetime(data.date_of_infraction, format="%Y%m%d")

# %%
data.date_of_infraction.value_counts().plot()
plt.ylabel("Daily Number of Infractions")
plt.title("2015")

# %%
data2014.date_of_infraction.value_counts().plot()
plt.ylabel("Daily Number of Infractions")
plt.title("2014")

# %%
x=data.date_of_infraction.values[0]

# %%
x= data.date_of_infraction.iloc[0]

# %%
days_of_week_d = {0: "Mon", 1: "Tue", 2:"Wed", 3:"Thu", 4:"Fri", 5:"Sat", 6:"Sun"}

# %%
days_of_week_infrances = data.date_of_infraction.map(lambda d: days_of_week_d[d.dayofweek])

# %%
dow_vc = days_of_week_infrances.value_counts()

# %%
dow_vc.index
# Out:
# Index([u'Tue', u'Thu', u'Wed', u'Fri', u'Sat', u'Mon', u'Sun'], dtype='object')

# %%
days_of_week_infrances_s = days_of_week_infrances[:10]

# %%
days_of_week_infrances_s
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# 5    3
# 6    3
# 7    3
# 8    3
# 9    3
# Name: date_of_infraction, dtype: int64

# %%
days_of_week_infrances.value_counts().plot(kind='bar')

# %%
data.date_of_infraction.map(lambda d : d.dvalue_counts().plot()
plt.ylabel("Daily Number of Infraction")

# %%
len(data.time_of_infraction)
# Out:
# 2168493

# %%
data.time_of_infraction.dropna()
# Out:
# 0            1.0
# 1            1.0
# 2            2.0
# 3            3.0
# 4            3.0
# 5            3.0
# 6            3.0
# 7            4.0
# 8            4.0
# 9            4.0
# 10           4.0
# 11           4.0
# 12           5.0
# 13           5.0
# 14           5.0
# 15           6.0
# 16           6.0
# 17           6.0
# 18           6.0
# 19           6.0
# 20           6.0
# 21           6.0
# 22           6.0
# 23           7.0
# 24           7.0
# 25           7.0
# 26           7.0
# 27           7.0
# 28           7.0
# 29           7.0
#            ...
# 668461    2321.0
# 668462    2322.0
# 668463    2323.0
# 668464    2325.0
# 668465    2326.0
# 668466    2326.0
# 668467    2327.0
# 668468    2328.0
# 668469    2329.0
# 668470    2330.0
# 668471    2330.0
# 668472    2333.0
# 668473    2334.0
# 668474    2336.0
# 668475    2337.0
# 668476    2339.0
# 668477    2340.0
# 668478    2341.0
# 668479    2341.0
# 668480    2343.0
# 668481    2345.0
# ...

# %%
data.time_of_infraction.ddescribe()
# Out:
# count    2.167063e+06
# mean     1.188662e+03
# std      6.045428e+02
# min      0.000000e+00
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max      2.359000e+03
# Name: time_of_infraction, dtype: float64

# %%
plt.hist(data.time_of_infraction.dropna(), bins=np.arange(0, 24.0, 1.0));
plt.xlabel("hour")
plt.ylabel("counts")
